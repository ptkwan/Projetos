# %% [markdown]
# # **Projeto de Final do primeiro módulo (Lógica de programação 1 com Python - ADA Tech & IFood** 🎲

# %% [markdown]
# ## **Sumário**
#
# -   [Definição do Problema](#definicao-do-problema)
# -   [As Recomendações](#recomendacoes)
# -   [Os Integrantes](#integrantes)
# -   [O que é o KNN?](#knn)
# -   [O Desenvolvimento](#desenvolvimento)
#     - 1 - [Executando os conjuntos de dados fornecidos](#1)
#     - 2 - [Criando a função `distancia_euclidiana`](#2)
#     - 3 - [Como decidir um empate?](#3)
#     - 4 - [Calculando as distâncias entres os pontos](#4)
#     - 5 - [Classificando os CPFs se baseando nas distâncias calculadas](#5)
#     - 6 - [Obtendo as novas classificações](#6)
# -   [Conclusão](#conclusao)

# %% [markdown]
# ## Definição do Problema 💡 <a name="definicao-do-problema"></a>
#
# Os dados que recebemos são referentes ao cadastro de clientes de uma empresa de logística fictícia. Nesse cadastro, há o quanto foi gasto pelo cliente nas últimas 4 compras, seu CPF e uma classificação de NPS: **Promotor**, **Neutro**, **Detrator**.
#
# O nosso objetivo é, a partir das últimas compras de uma lista de 120 clientes que já deram uma nota NPS, estimar essa calssificação para aqueles que ainda não classificaram, afim de melhorar o atendimento desses novos clientes.
#
# Os dados recebidos seguem o seguinte padrão:
#
# ```
# [CPF (int), Classificação NPS (string), Valor das 4 últimas compras (tupla com floats)]
# ```
#
# Para contextualizar, o [NPS](https://assets-global.website-files.com/633ec8b202a7496fb9c9dda9/64020daae50d701ac16ebd7a_Net%20Promoter%20Score.jpeg), ou "Net Promoter Score" é uma métrica utilizada pelas empresas para entenderem o quão propensos seus clientes são em voltar a fazer negócios

# %% [markdown]
# ## As recomendações  🌟 <a name="recomendacoes"></a>
#
# Devemos fazer o programa utilizando somente:
#
# <br>
#
# - Funções próprias e funções *built in* do próprio *Python*.
# - Estruturas e laços de repetições.
# - Listas.
# - Tuplas.

# %% [markdown]
# ## Integrantes: 👥 <a name="integrantes"></a>
#
#
#
# *   ### Alan Gonçalves
# *   ### Élen Silva Almeida
# *   ### Gabriel Matina
# *   ### Gustavo Dell Anhol Oliveira
# *   ### Patrick Kwan

# %% [markdown]
# ## O que é o KNN? 🤔 <a name="knn"></a>
#
# <br>
#
# O KNN (K-nearest neighbors, ou “K-vizinhos mais próximos”) costuma ser um dos primeiros algoritmos aprendidos por iniciantes no mundo do aprendizado de máquina. Em resumo, o KNN tenta classificar cada amostra de um conjunto de dados avaliando sua distância em relação aos vizinhos mais próximos. Se os vizinhos mais próximos forem majoritariamente de uma classe, a amostra em questão será classificada nesta categoria.
#
# <br>
#
# Ou seja, escolhemos um número **"K"** de "vizinhos próximos" para definirmos a classificação do item que não está classificado. E para esse projeto decidimos definir o nosso valor de **"K"** igual a 5
#
# <br>
#
# Aqui, um vídeo de explicação sobre o Algoritmo KNN pela empresa [IA Expert Academy](https://www.youtube.com/watch?v=KBh4vnsCDc4).
#
#
# ---
#
#
#
# ## Links Úteis
#
# #### Definições
# - ["Primeira" aparição do modelo](https://apps.dtic.mil/dtic/tr/fulltext/u2/a800276.pdf)
#
# #### Casos de uso
# - [Click Stream](https://www.sciencedirect.com/science/article/pii/S221083271400026X#:~:text=The%20K%2DNearest%20Neighbor%20classification,a%20given%20time%20%5B24%5D)
# - [Battery life](https://www.sciencedirect.com/science/article/abs/pii/S0959652619342799)
# - [Mahalanobis Distance](https://jmlr.csail.mit.edu/papers/volume10/weinberger09a/weinberger09a.pdf)
#
# #### Ferramentas de Dataviz sobre o KNN
#
# - [Playground 1](https://ml-playground.com/)
# - [Playground 2](https://www.ccom.ucsd.edu/~cdeotte/programs/classify.html)

# %% [markdown]
# ## O Desenvolvimento 🛠️ <a name="desenvolvimento"></a>

# %% [markdown]
# ## 1.  Executando os conjuntos de dados fornecidos. <a name="1"></a>
#
# > Para iniciar, apenas executamos os dados fornecidos, que contém 120 usuários já classificados e os 30 usuários que ainda temos que classificar

# %%
data = [[66707599984, 'Promotor', (51.00, 35.00, 14.00, 20.0)],
 [55695397315, 'Promotor', (49.00, 30.00, 14.00, 20.0)],
 [63743886918, 'Promotor', (47.00, 32.00, 13.00, 20.0)],
 [55941368774, 'Promotor', (46.00, 31.00, 15.00, 20.0)],
 [75486280874, 'Promotor', (50.00, 36.00, 14.00, 20.0)],
 [53164949799, 'Promotor', (54.00, 39.00, 17.00, 40.0)],
 [39898704131, 'Promotor', (46.00, 34.00, 14.00, 30.0)],
 [53740901207, 'Promotor', (50.00, 34.00, 15.00, 20.0)],
 [51735950236, 'Promotor', (44.00, 29.00, 14.00, 20.0)],
 [47305108951, 'Promotor', (49.00, 31.00, 15.00, 10.0)],
 [63858864633, 'Promotor', (54.00, 37.00, 15.00, 20.0)],
 [53363167240, 'Promotor', (48.00, 34.00, 16.00, 20.0)],
 [72133754195, 'Promotor', (48.00, 30.00, 14.00, 10.0)],
 [52802483512, 'Promotor', (43.00, 30.00, 11.00, 10.0)],
 [57925287214, 'Promotor', (48.00, 34.00, 19.00, 20.0)],
 [74354632224, 'Promotor', (50.00, 30.00, 16.00, 20.0)],
 [64020216626, 'Promotor', (50.00, 34.00, 16.00, 40.0)],
 [78223722856, 'Promotor', (52.00, 35.00, 15.00, 20.0)],
 [58245228846, 'Promotor', (52.00, 34.00, 14.00, 20.0)],
 [74490686776, 'Promotor', (47.00, 32.00, 16.00, 20.0)],
 [48646824781, 'Promotor', (48.00, 31.00, 16.00, 20.0)],
 [77381458676, 'Promotor', (54.00, 34.00, 15.00, 40.0)],
 [41615431874, 'Promotor', (52.00, 41.00, 15.00, 10.0)],
 [52163844491, 'Promotor', (55.00, 42.00, 14.00, 20.0)],
 [70276304567, 'Promotor', (49.00, 31.00, 15.00, 20.0)],
 [69119828185, 'Promotor', (50.00, 32.00, 12.00, 20.0)],
 [65441690046, 'Promotor', (55.00, 35.00, 13.00, 20.0)],
 [56457227894, 'Promotor', (49.00, 36.00, 14.00, 10.0)],
 [46939428126, 'Promotor', (44.00, 30.00, 13.00, 20.0)],
 [60979942480, 'Promotor', (51.00, 34.00, 15.00, 20.0)],
 [41648583220, 'Promotor', (50.00, 35.00, 13.00, 30.0)],
 [50376331791, 'Promotor', (45.00, 23.00, 13.00, 30.0)],
 [67008801023, 'Promotor', (44.00, 32.00, 13.00, 20.0)],
 [72149193419, 'Promotor', (50.00, 35.00, 16.00, 60.0)],
 [62830733382, 'Promotor', (51.00, 38.00, 19.00, 40.0)],
 [56716675811, 'Promotor', (48.00, 30.00, 14.00, 30.0)],
 [61089667146, 'Promotor', (51.00, 38.00, 16.00, 20.0)],
 [47795509468, 'Promotor', (46.00, 32.00, 14.00, 20.0)],
 [60899885693, 'Promotor', (53.00, 37.00, 15.00, 20.0)],
 [53433670705, 'Promotor', (50.00, 33.00, 14.00, 20.0)],
 [54850120580, 'Neutro', (70.00, 32.00, 47.00, 14.00)],
 [71457789994, 'Neutro', (64.00, 32.00, 45.00, 15.00)],
 [67692777563, 'Neutro', (69.00, 31.00, 49.00, 15.00)],
 [43133573182, 'Neutro', (55.00, 23.00, 40.00, 13.00)],
 [55150612815, 'Neutro', (65.00, 28.00, 46.00, 15.00)],
 [48211725243, 'Neutro', (57.00, 28.00, 45.00, 13.00)],
 [76686463776, 'Neutro', (63.00, 33.00, 47.00, 16.00)],
 [71971000560, 'Neutro', (49.00, 24.00, 33.00, 10.00)],
 [40307235992, 'Neutro', (66.00, 29.00, 46.00, 13.00)],
 [44826533081, 'Neutro', (52.00, 27.00, 39.00, 14.00)],
 [45735414894, 'Neutro', (59.00, 32.00, 48.00, 18.00)],
 [57137146514, 'Neutro', (61.00, 28.00, 40.00, 13.00)],
 [53657058251, 'Neutro', (63.00, 25.00, 49.00, 15.00)],
 [52941460485, 'Neutro', (61.00, 28.00, 47.00, 12.00)],
 [44306600683, 'Neutro', (64.00, 29.00, 43.00, 13.00)],
 [43460747924, 'Neutro', (66.00, 30.00, 44.00, 14.00)],
 [75590376075, 'Neutro', (68.00, 28.00, 48.00, 14.00)],
 [68267282206, 'Neutro', (67.00, 30.00, 50.00, 17.00)],
 [77567920298, 'Neutro', (60.00, 29.00, 45.00, 15.00)],
 [67600419504, 'Neutro', (57.00, 26.00, 35.00, 10.00)],
 [44902189811, 'Neutro', (55.00, 24.00, 38.00, 11.00)],
 [62966866614, 'Neutro', (55.00, 24.00, 37.00, 10.00)],
 [56182108880, 'Neutro', (58.00, 27.00, 39.00, 12.00)],
 [78299785392, 'Neutro', (60.00, 27.00, 51.00, 16.00)],
 [45206071878, 'Neutro', (54.00, 30.00, 45.00, 15.00)],
 [57381925887, 'Neutro', (60.00, 34.00, 45.00, 16.00)],
 [65654934891, 'Neutro', (67.00, 31.00, 47.00, 15.00)],
 [56130640481, 'Neutro', (63.00, 23.00, 44.00, 13.00)],
 [59667611672, 'Neutro', (56.00, 30.00, 41.00, 13.00)],
 [40349334385, 'Neutro', (55.00, 25.00, 40.00, 13.00)],
 [68422640081, 'Neutro', (55.00, 26.00, 44.00, 12.00)],
 [55245923439, 'Neutro', (61.00, 30.00, 46.00, 14.00)],
 [51286696873, 'Neutro', (58.00, 26.00, 40.00, 12.00)],
 [41065279767, 'Neutro', (50.00, 23.00, 33.00, 10.00)],
 [42866454119, 'Neutro', (56.00, 27.00, 42.00, 13.00)],
 [61962944542, 'Neutro', (57.00, 30.00, 42.00, 12.00)],
 [48623501235, 'Neutro', (57.00, 29.00, 42.00, 13.00)],
 [49475220139, 'Neutro', (62.00, 29.00, 43.00, 13.00)],
 [52245218531, 'Neutro', (51.00, 25.00, 30.00, 11.00)],
 [50932926697, 'Neutro', (57.00, 28.00, 41.00, 13.00)],
 [47432932248, 'Detrator', (63.00, 33.00, 60.00, 25.00)],
 [39321991579, 'Detrator', (58.00, 27.00, 51.00, 19.00)],
 [46283759608, 'Detrator', (71.00, 30.00, 59.00, 21.00)],
 [56996272538, 'Detrator', (63.00, 29.00, 56.00, 18.00)],
 [77232189978, 'Detrator', (65.00, 30.00, 58.00, 22.00)],
 [77183282421, 'Detrator', (76.00, 30.00, 66.00, 21.00)],
 [42857147573, 'Detrator', (49.00, 25.00, 45.00, 17.00)],
 [39331584043, 'Detrator', (73.00, 29.00, 63.00, 18.00)],
 [48130345228, 'Detrator', (67.00, 25.00, 58.00, 18.00)],
 [71422443953, 'Detrator', (72.00, 36.00, 61.00, 25.00)],
 [72508507904, 'Detrator', (69.00, 32.00, 57.00, 23.00)],
 [41188727558, 'Detrator', (56.00, 28.00, 49.00, 20.00)],
 [61358776640, 'Detrator', (77.00, 28.00, 67.00, 20.00)],
 [66934042323, 'Detrator', (63.00, 27.00, 49.00, 18.00)],
 [40622495567, 'Detrator', (67.00, 33.00, 57.00, 21.00)],
 [57221661311, 'Detrator', (72.00, 32.00, 60.00, 18.00)],
 [45159362930, 'Detrator', (62.00, 28.00, 48.00, 18.00)],
 [45018975174, 'Detrator', (61.00, 30.00, 49.00, 18.00)],
 [70685429140, 'Detrator', (64.00, 28.00, 56.00, 21.00)],
 [61808723477, 'Detrator', (72.00, 30.00, 58.00, 16.00)],
 [56363906548, 'Detrator', (74.00, 28.00, 61.00, 19.00)],
 [39646194720, 'Detrator', (79.00, 38.00, 64.00, 20.00)],
 [55385494438, 'Detrator', (64.00, 28.00, 56.00, 22.00)],
 [75796138061, 'Detrator', (63.00, 28.00, 51.00, 15.00)],
 [53595767857, 'Detrator', (61.00, 26.00, 56.00, 14.00)],
 [48758828080, 'Detrator', (77.00, 30.00, 61.00, 23.00)],
 [58387651356, 'Detrator', (63.00, 34.00, 56.00, 24.00)],
 [72846931192, 'Detrator', (64.00, 31.00, 55.00, 18.00)],
 [47046896346, 'Detrator', (60.00, 30.00, 48.00, 18.00)],
 [69730292799, 'Detrator', (69.00, 31.00, 54.00, 21.00)],
 [48177836349, 'Detrator', (67.00, 31.00, 56.00, 24.00)],
 [57976326635, 'Detrator', (69.00, 31.00, 51.00, 23.00)],
 [55710813002, 'Detrator', (58.00, 27.00, 51.00, 19.00)],
 [64028580439, 'Detrator', (68.00, 32.00, 59.00, 23.00)],
 [49962942971, 'Detrator', (67.00, 33.00, 57.00, 25.00)],
 [47250893163, 'Detrator', (67.00, 30.00, 52.00, 23.00)],
 [75559276274, 'Detrator', (63.00, 25.00, 50.00, 19.00)],
 [58529878272, 'Detrator', (65.00, 30.00, 52.00, 20.00)],
 [76005896622, 'Detrator', (62.00, 34.00, 54.00, 23.00)],
 [49212614633, 'Detrator', (59.00, 30.00, 51.00, 18.00)]]

no_class = [[45926320819, '', (58.00, 40.00, 12.00, 20.0)],
 [52559670741, '', (57.00, 44.00, 15.00, 40.0)],
 [59016004832, '', (54.00, 39.00, 13.00, 40.0)],
 [66175672425, '', (51.00, 35.00, 14.00, 30.0)],
 [53330429526, '', (57.00, 38.00, 17.00, 30.0)],
 [43765563403, '', (51.00, 38.00, 15.00, 30.0)],
 [68020822591, '', (54.00, 34.00, 17.00, 20.0)],
 [53939481689, '', (51.00, 37.00, 15.00, 40.0)],
 [47014057561, '', (46.00, 36.00, 10.00, 20.0)],
 [57183542047, '', (51.00, 33.00, 17.00, 50.0)],
 [68518284363, '', (50.00, 20.00, 35.00, 10.00)],
 [65806049885, '', (59.00, 30.00, 42.00, 15.00)],
 [54128073086, '', (60.00, 22.00, 40.00, 10.00)],
 [41306785494, '', (61.00, 29.00, 47.00, 14.00)],
 [65234831039, '', (56.00, 29.00, 36.00, 13.00)],
 [50964498067, '', (67.00, 31.00, 44.00, 14.00)],
 [50810951429, '', (56.00, 30.00, 45.00, 15.00)],
 [48765044397, '', (58.00, 27.00, 41.00, 10.00)],
 [41960083761, '', (62.00, 22.00, 45.00, 15.00)],
 [76657763082, '', (56.00, 25.00, 39.00, 11.00)],
 [64726487742, '', (65.00, 32.00, 51.00, 20.00)],
 [75746566283, '', (64.00, 27.00, 53.00, 19.00)],
 [78576734793, '', (68.00, 30.00, 55.00, 21.00)],
 [56440141847, '', (57.00, 25.00, 50.00, 20.00)],
 [66827423000, '', (58.00, 28.00, 51.00, 24.00)],
 [45267873396, '', (64.00, 32.00, 53.00, 23.00)],
 [46387191493, '', (65.00, 30.00, 55.00, 18.00)],
 [54273611732, '', (77.00, 38.00, 67.00, 22.00)],
 [75135392881, '', (77.00, 26.00, 69.00, 23.00)],
 [64703873108, '', (60.00, 22.00, 50.00, 15.00)]]

# no_class recebe 30 elementos a serem classificados
# data recebe 120 elementos já classificados

# %% [markdown]
# ## 2. Criando a função `distancia_euclidiana` que verifica a distancia entre 2 pontos.<br> <a name="2"></a>
# >Esse é o coração do projeto, a nossa ideia foi criar não só uma função para ser utilizada nesse conjunto de dados específicos, mas sim uma que funcionaria para calcular a distância com quaisquer quantidades de "dimensões"

# %%
def distancia_euclidiana(ponto1, ponto2):
    somatoria = 0
    for i in range(len(ponto1)):
        somatoria += (ponto1[i] - ponto2[i]) ** 2
    return somatoria ** 0.5

# %% [markdown]
# ## 3. Como decidir um empate?
#
# >A função `desvioPadrao` foi criada para que, se ouvesse dois pontos empatados em relação a distância, decidiríamos a menor distância pelo desvio padrão. <a name="3"></a>

# %%
def calcular_desvio_padrao(lista):
  # Calcular a média
  media = (lista[0] + lista[1]) / 2

  # Calcular os desvios
  desvio1 = (lista[0] - media)
  desvio2 = (lista[1] - media)

  # Calcular a variância
  variancia = (desvio1 ** 2 + desvio2 ** 2) / 2

  # Calcula o desvio padrão
  desvio_padrao = (variancia) ** 0.5

  # Retorna o resultado
  return desvio_padrao

# %% [markdown]
# ## 4. Calculando as distâncias entres os pontos
#
# > A Função `matriz_de_distancias` realiza o cálculo de distância euclidiana entre cada um dos 30 CPF's que precisam ser classificados e os 120 já classificados, retornando uma matriz 2x2 relacionando a distância entre os pontos de `no_class` e `data` <a name="4"></a>

# %%
def matriz_de_distancias(data,no_class):

  # Armazena apenas as classes dos itens de "data"
  lista_de_classes = []

  # Armazena a distância de um ponto com o outro ("data" e "no_class")
  distancias_de_um_ponto = []

  # Armazena a distância de todos os pontos ("data" e "no_class")
  distancias_todos_pontos = []

  # Variáveis temporárias para tratar e relacionar as classes com as distâncias
  zip_distancias_classes = []
  distancias_classes_lista = []
  lista_distancia = []

  # Retorna a distância e a classe em tuplas
  distancias_classificadas = []

  # Preenchendo a lista com as classes dos itens de "data"
  for i in range(len(data)):
      lista_de_classes.append(data[i][1])

  # Devolve uma Matriz 2x2 relacionando a distância entre os pontos de "no_class" e "data" com seus respectivos índices
  for i in range(len(no_class)):
    for j in range(len(data)):
      distancias_de_um_ponto.append(distancia_euclidiana(no_class[i][2], data[j][2]))

    # Aqui armazenamos a distância de cada um dos pontos em uma lista que contém todos os pontos
    distancias_todos_pontos.append(distancias_de_um_ponto)

    # Aqui zeramos a variável para pegar o próximo ponto e não misturar com os outros, depois salvar novamente
    distancias_de_um_ponto = []

    # Aqui juntamos todas as distâncias com suas respectivas classes, devolvendo em tupla
    zip_distancias_classes = list(zip(distancias_todos_pontos[i],lista_de_classes))
    distancias_classificadas.append(zip_distancias_classes)

    # Aqui transformamos a distancias_classificadas em lista para podermos trabalhar com os valores
    [lista_distancia.append(list(distancias_classificadas[i][k])) for k in range(len(data))]

    distancias_classes_lista.append(lista_distancia)

    # Limpa a lista para reiniciar o processo de iteração novamente
    lista_distancia = []

  return distancias_classes_lista

# %% [markdown]
# ##5. Classificando os CPFs se baseando nas distâncias calculadas
#
# > A função `contagem_de_classe` irá identificar qual a classe de cada CPF não classificado baseado nas **"K"** distâncias encontradas (como dito antes, definimos K como 5) <a name="5"></a>

# %%
def contagem_de_classe(lista):

    pro = 0 # "Promotor"
    neu = 0 # "Neutro"
    det = 0 # "Detrator"

    lista_temp = lista.copy()

    # Organiza a lista e seleciona os 5 primeiros
    lista_temp.sort()
    lista_k_menores = lista_temp[:5] # Aqui pegamos os 5 primeiros (valor que definimos para o "K")

    classe_definida = ""

    # Fazendo a contagem de todas as ocorrências das classes
    for _, palavra in lista_k_menores:
        if palavra == 'Promotor':
            pro += 1
        elif palavra == 'Neutro':
            neu += 1
        elif palavra == 'Detrator':
            det += 1

    # Cria uma lista determinando a quantidade de cada ocorrência de classe
    qtde_classes = [pro, neu, det]
    cont_classes = []

    # Verifica o que mais apareceu e armazena na "qtde_classes"
    for i in range(len(qtde_classes)):
        maior = max(qtde_classes)
        # Conta quantas ocorrências houveram do maior item
        ocorrencia_maior = qtde_classes.count(maior)

        # Combina os itens da "qtde_classes" com as respectivas classes
        cont_classes = list(zip(qtde_classes,["Promotor","Neutro","Detrator"]))

        # Ordena a lista da classe que mais apareceu para a que menos apareceu
        cont_classes.sort(reverse = True)


    # Caso haja mais que uma ocorrência, houve empate, portanto ele executa o "If"
    if ocorrencia_maior > 1:
        classe_1 = cont_classes[0][1]
        classe_2 = cont_classes[1][1]

        print(f"\nHouve um empate entre {classe_1} e {classe_2}")

        # Armazena os valores de distância de cada uma das classes que empataram
        distancias_1 = []
        distancias_2 = []

        # Localizar quais as distâncias das classes que empataram para calcular o desvio padrão
        for i in range(len(lista_k_menores)):
            if classe_1 == lista_k_menores[i][1]:
                distancias_1.append(lista_k_menores[i][0])
            elif classe_2 == lista_k_menores[i][1]:
                distancias_2.append(lista_k_menores[i][0])

        # Calcula o desvio padrão
        desvio1 = calcular_desvio_padrao(distancias_1)
        desvio2 = calcular_desvio_padrao(distancias_2)

        print(f"\nO desvio padrao da {classe_1} é = {desvio1}")
        print(f"\nO desvio padrao da {classe_2} é = {desvio2}")

        if desvio1 < desvio2:
            classe_definida = classe_1
            print(f"\nComo o desvio padrao da {classe_1} é menor, temos a menor dispersao dos dados, portanto classificamos como {classe_1}")
            return classe_definida

        elif desvio2 < desvio1:
            classe_definida = classe_2
            print(f"\nComo o desvio padrao da {classe_2} é menor, temos a menor dispersao dos dados, portanto classificamos como {classe_2}")
            return classe_definida

        else:
            print("\nOs desvios são iguais, portanto podemos fazer um random Tie Break")
            classe_definida = classe_1
            return classe_definida

    # Se nao for empate, ele vai simplesmente salvar o primeiro valor
    else:
        classe_definida = cont_classes[0][1]
        return classe_definida

# %% [markdown]
# ##6. Obtendo as novas classificações <a name="6"></a>
#
# > Aqui, criamos uma função simples para imprimir na tela os 30 usuários, antes sem classificações, agora classificados

# %%
def define_classificacoes():
    classificacao_final = []

    print("As classificações são:\n")

    for i in range(len(matriz_de_distancias(data,no_class))):
      classificacao_final.append(contagem_de_classe(matriz_de_distancias(data, no_class)[i]))
      lista_principal = no_class.copy()

    for i in range(len(no_class)):
      lista_principal[i][1] = classificacao_final[i]

    for i in range(len(matriz_de_distancias(data,no_class))):
      print(lista_principal[i])

# %%
define_classificacoes()
# Out:
# As classificações são:
#
# [45926320819, 'Promotor', (58.0, 40.0, 12.0, 20.0)]
# [52559670741, 'Promotor', (57.0, 44.0, 15.0, 40.0)]
# [59016004832, 'Promotor', (54.0, 39.0, 13.0, 40.0)]
# [66175672425, 'Promotor', (51.0, 35.0, 14.0, 30.0)]
# [53330429526, 'Promotor', (57.0, 38.0, 17.0, 30.0)]
# [43765563403, 'Promotor', (51.0, 38.0, 15.0, 30.0)]
# [68020822591, 'Promotor', (54.0, 34.0, 17.0, 20.0)]
# [53939481689, 'Promotor', (51.0, 37.0, 15.0, 40.0)]
# [47014057561, 'Promotor', (46.0, 36.0, 10.0, 20.0)]
# [57183542047, 'Promotor', (51.0, 33.0, 17.0, 50.0)]
# [68518284363, 'Neutro', (50.0, 20.0, 35.0, 10.0)]
# [65806049885, 'Neutro', (59.0, 30.0, 42.0, 15.0)]
# [54128073086, 'Neutro', (60.0, 22.0, 40.0, 10.0)]
# [41306785494, 'Neutro', (61.0, 29.0, 47.0, 14.0)]
# [65234831039, 'Neutro', (56.0, 29.0, 36.0, 13.0)]
# [50964498067, 'Neutro', (67.0, 31.0, 44.0, 14.0)]
# [50810951429, 'Neutro', (56.0, 30.0, 45.0, 15.0)]
# [48765044397, 'Neutro', (58.0, 27.0, 41.0, 10.0)]
# ...

# %% [markdown]
# ## Conclusão 🎉 <a name="conclusao"></a>
#
# Esse com certeza foi um projeto desafiador, mas, realizar esse projeto ao lado de colegas dedicados e talentosos proporcionou uma experiência única. Ao longo do projeto, tivemos a oportunidade de desenvolver e aprimorar várias habilidades, não técnicas mas também as nossas habilidades interpessoais, como: Comunicação, Gestão de Tempo, Trabalho em Equipe, Liderança, Resiliência e Adaptação.
#
# <br>
#
# Gostariamos de agradecer a toda equipe da ADA Tech e ao IFood por nos proporcionar um curso tão desafiador, e que está nos proporcionando experiências únicas e também ao professor Wenderson Alexandre👨🏽‍🏫 por toda a sua paciência e resiliência para com todos nós alunos
#
# <br>
#
# Acreditamos que sozinhos chegamos rápido, porém juntos vamos mais longe. 🚀
